# %% [markdown]
# <a href="https://colab.research.google.com/github/GENTLEW1ND/Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library
#
# Usefull for Data Processing and Analytics

# %% [markdown]
# Pandas Data Frame:
#
# Pandas DataFrame is two-Dimentional tabular data structure with labeled axes (rows and columns).

# %%
#importing the pandas library

import pandas as pd
import numpy as np

# %% [markdown]
# Creating a Pandas DataFrame

# %%
# importing the california housing test csv file
df = pd.read_csv("sample_data/california_housing_test.csv")
print(df)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# california_df = pd.DataFrame(df.data, columns=df.housing_median_age)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
diabetis_df = pd.read_csv("/content/diabetes.csv")
print(diabetis_df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
type(diabetis_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetis_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetis_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from a excel file to a pandas Dataframe:
#
# pd.read_excel("file_path")

# %% [markdown]
# Exporting a DataFrame to an csv file

# %%
df.to_csv("california_df.csv")

# %% [markdown]
# Exporting a DataFrame to an excel file

# %%
df.to_excel("california_df.xlsx")

# %% [markdown]
# Creating a dataFrame with random values
#
# for that import the numpy library

# %%
random_df = pd.DataFrame(np.random.rand(20,10))
print(random_df)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.914694  0.972194  0.679271  0.950197  0.810896  0.142954  0.743730
# 1   0.884401  0.658032  0.985114  0.291066  0.533308  0.511189  0.097890
# 2   0.723617  0.826944  0.378544  0.560294  0.435107  0.122910  0.807864
# 3   0.253459  0.145770  0.097290  0.377840  0.480898  0.597923  0.659394
# 4   0.397587  0.544176  0.055892  0.052698  0.390803  0.972888  0.799257
# 5   0.689437  0.796092  0.391288  0.772652  0.380270  0.247272  0.223079
# 6   0.260676  0.956240  0.581955  0.866281  0.887452  0.006192  0.208809
# 7   0.203471  0.318848  0.063880  0.929833  0.024078  0.733910  0.385960
# 8   0.322422  0.759572  0.239243  0.561870  0.189812  0.869792  0.506203
# 9   0.788945  0.022942  0.352560  0.182840  0.731100  0.084775  0.961890
# 10  0.808908  0.423486  0.310851  0.370744  0.602029  0.789806  0.344928
# 11  0.783181  0.505260  0.776530  0.240521  0.811210  0.017378  0.322834
# ...

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.914694  0.972194  0.679271  0.950197  0.810896  0.142954  0.743730
# 1  0.884401  0.658032  0.985114  0.291066  0.533308  0.511189  0.097890
# 2  0.723617  0.826944  0.378544  0.560294  0.435107  0.122910  0.807864
# 3  0.253459  0.145770  0.097290  0.377840  0.480898  0.597923  0.659394
# 4  0.397587  0.544176  0.055892  0.052698  0.390803  0.972888  0.799257
#
#           7         8         9
# 0  0.527832  0.282013  0.273983
# 1  0.248775  0.803938  0.801826
# 2  0.799376  0.143020  0.926933
# 3  0.996632  0.321442  0.427794
# 4  0.854801  0.308933  0.470663
